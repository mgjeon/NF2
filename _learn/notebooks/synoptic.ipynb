# %%
from sunpy.map import Map

# %%
syn_map = Map('../data/fd_2173/hmi.synoptic_mr_polfil_720s.2173.Mr_polfil.fits')

# %%
syn_map.peek()
# Out:
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hgln_obs,dsun_obs,hglt_obs
# For frame 'heliographic_carrington' the following metadata is missing: crlt_obs,crln_obs,dsun_obs
#  [sunpy.map.mapbase]

# %%
syn_map.meta['content']
# Out:
# 'Carrington Synoptic Chart Of Br Field'

# %%
syn_map_Bp = Map('../data/fd_2173/hmi.b_synoptic.2173.Bp.fits')

# %%
syn_map_Bp.peek()
# Out:
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hgln_obs,dsun_obs,hglt_obs
# For frame 'heliographic_carrington' the following metadata is missing: crlt_obs,crln_obs,dsun_obs
#  [sunpy.map.mapbase]

# %%
syn_map_Bp.meta['content']
# Out:
# 'Carrington Synoptic Chart Of Vector Magnetic Field'

# %%
syn_map_Br = Map('../data/fd_2173/hmi.b_synoptic.2173.Br.fits')

# %%
syn_map_Br.peek()
# Out:
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# WARNING: SunpyMetadataWarning: Missing metadata for observer: assuming Earth-based observer.
# For frame 'heliographic_stonyhurst' the following metadata is missing: hgln_obs,dsun_obs,hglt_obs
# For frame 'heliographic_carrington' the following metadata is missing: crlt_obs,crln_obs,dsun_obs
#  [sunpy.map.mapbase]

# %%
syn_map_Br.meta['content']
# Out:
# 'Carrington Synoptic Chart Of Vector Magnetic Field'

# %%
syn_map_Br.data
# Out:
# array([[  1.9741023 ,   3.1740217 ,   1.8002695 , ...,  12.2901    ,
#          11.054756  ,  15.741312  ],
#        [ -0.10664888,   0.17826778,  -0.43641967, ...,  10.186999  ,
#          14.420688  ,  26.415339  ],
#        [  1.6449581 ,   9.67052   ,   9.275633  , ..., -21.400707  ,
#         -30.55863   , -36.60732   ],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], dtype='>f4')

# %%
syn_map.data
# Out:
# array([[-4.8, -4.8, -4.8, ..., -4.8, -4.8, -4.8],
#        [-4.8, -4.8, -4.8, ..., -4.8, -4.8, -4.8],
#        [-4.9, -4.9, -4.9, ..., -4.9, -4.9, -4.9],
#        ...,
#        [ 0.9,  0.9,  0.9, ...,  0.9,  0.9,  0.9],
#        [ 0.9,  0.9,  0.9, ...,  0.9,  0.9,  0.9],
#        [ 0.9,  0.9,  0.9, ...,  0.9,  0.9,  0.9]])
